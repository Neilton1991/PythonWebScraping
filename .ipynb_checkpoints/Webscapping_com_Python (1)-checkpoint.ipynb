# %% [markdown]
# **PORTFOLIO**

# %%
from urllib.request import Request, urlopen
import bs4
import pandas as pd
import time
import pyodbc

# %%
agente = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:106.0) Gecko/20100101 Firefox/106.0'
headers = {'User-Agent': agente}
pd.options.display.max_colwidth = 100

# %%
#WEBSCRAPPING COM PANDAS
def ConsultaWeb(url):
    try:
        req = Request(url, headers = headers)
        response = urlopen(req)
        return response.read()

    except:
        pass
    
def captura_html_pagina(url):
    html = ConsultaWeb(url)
    soup = bs4.BeautifulSoup(html, 'html.parser')    
    return soup

def Cabecalho(html):
    dt = html.find_all('dt')
    dd = html.find_all('dd')
    dic = {}
    for i in range(len(dt)):
        x = dt[i].get_text()
        y = dd[i].get_text()
        dic[x] = y
    return dic

def ChecaErro(url):
    html = captura_html_pagina(url)
    Erro = html.find(class_="col-10")
    if(Erro==None):
        return True
    else:
        return False

def ProposicaoCabecalho(proposicao, ano):
    url = 'https://www.legislador.com.br//LegisladorWEB.ASP?WCI=ProposicaoTexto&ID=3&TPProposicao=1&nrProposicao='+str(proposicao)+'&aaProposicao='+str(ano)
    html = captura_html_pagina(url)
    dic = Cabecalho(html)
    dic['Proposição'] = proposicao
    dic['Ano'] = ano
    dic['Texto'] = html.p.get_text()
    return dic

# %%
def SQLSelect(query):
    
    conn = pyodbc.connect('Trusted_Connection=yes', 
                          driver = '{ODBC Driver 17 for SQL Server}',
                          server = 'localhost', 
                          database = 'Indaial',
                          UID='sa',
                          PWD='Assimehfoda1'
                         )

    out = pd.read_sql_query(query,conn)
    return out
    
def SQLInsertProposicoes(TabelaProposicoes):
    
    base = pd.DataFrame(columns=['Reunião', 'Deliberação', 'Situação', 'Assunto', 'Autor', 'Proposição', 'Ano', 'Texto'])
    TabelaProposicoes = base.append(TabelaProposicoes).fillna('')

    conn = pyodbc.connect('Trusted_Connection=yes', 
                          driver = '{ODBC Driver 17 for SQL Server}',
                          server = 'localhost', 
                          database = 'Indaial',
                          UID='sa',
                          PWD='Assimehfoda1'

                         )

    cursor = conn.cursor()

    for index, row in TabelaProposicoes.iterrows():

        cursor.execute('''

            INSERT INTO Proposicoes (
                DataReuniao,
                DataDeliberacao,
                Situacao,
                Assunto,
                Autor,
                Proposicao,
                Ano,
                Texto
            ) 
            values(?,?,?,?,?,?,?,?)''', 

            row['Reunião'], 
            row['Deliberação'], 
            row['Situação'], 
            row['Assunto'], 
            row['Autor'], 
            row['Proposição'], 
            row['Ano'], 
            row['Texto']

        )

    conn.commit()
    cursor.close()
    
def SQLTruncate(NomeTabela):

    conn = pyodbc.connect('Trusted_Connection=yes', 
                          driver = '{ODBC Driver 17 for SQL Server}',
                          server = 'localhost', 
                          database = 'Indaial',
                          UID='sa',
                          PWD='Assimehfoda1'

                         )

    cursor = conn.cursor()

    cursor.execute(f'''

                   TRUNCATE TABLE {NomeTabela}

                   ''')

    conn.commit()
    cursor.close()

def InsereProximaProposicao(ano):

    # Busca última proposição cadastrada
    dados_ano = SQLSelect(f'select Proposicao = max(Proposicao) from Proposicoes where Ano = {ano}')
    ultima_proposicao = dados_ano['Proposicao'].loc[0]

    # Verifica se foi identificado lançamento naquele ano
    if ultima_proposicao == None:
        proxima_proposicao = 1
    else:
        proxima_proposicao = int(ultima_proposicao) + 1 

    # Captura e Insere dados na tabela
    dados = ProposicaoCabecalho(proxima_proposicao,ano)
    tabela = pd.DataFrame([dados])
    SQLInsertProposicoes(tabela)
    
def BuscaGravaDadosAno(ano, quantidade = 10, erros_admissiveis = 30, segundos_espera = 0):

    # erros
    erros = 0
    qty = 1 #preposição
    
    # variaveis para loop
    i = 1
    lista = []
    
    while erros <= erros_admissiveis and qty <= quantidade:

        try:
            qty += 1
            url = 'https://www.legislador.com.br//LegisladorWEB.ASP?WCI=ProposicaoTexto&ID=3&TPProposicao=1&nrProposicao='+str(qty)+'&aaProposicao='+str(ano)
            if(ChecaErro(url)):
                InsereProximaProposicao(ano)
            else:
                erros+=1
        except:
            erros += 1
            pass

        time.sleep(segundos_espera)

        # carregamento incremental das variáveis
        i +=1

# %%
ano_inicial = 1996
ano_final = 2022

for i in list(range(ano_inicial, ano_final+1)):
    print('Iniciando gravação dos dados do ano: ',i)
    try:
        BuscaGravaDadosAno(i, quantidade = 999999999999)
    except:
        pass
    
print('Inserção finalizada 😁')
# Out:
# Iniciando gravação dos dados do ano:  1996
# Iniciando gravação dos dados do ano:  1997
# Iniciando gravação dos dados do ano:  1998
# Iniciando gravação dos dados do ano:  1999
# Iniciando gravação dos dados do ano:  2000
# Iniciando gravação dos dados do ano:  2001
# Iniciando gravação dos dados do ano:  2002
# Iniciando gravação dos dados do ano:  2003
# Iniciando gravação dos dados do ano:  2004
# Iniciando gravação dos dados do ano:  2005
# Iniciando gravação dos dados do ano:  2006
# Iniciando gravação dos dados do ano:  2007
# Iniciando gravação dos dados do ano:  2008
# Iniciando gravação dos dados do ano:  2009
# Iniciando gravação dos dados do ano:  2010
# Iniciando gravação dos dados do ano:  2011
# Iniciando gravação dos dados do ano:  2012
# Iniciando gravação dos dados do ano:  2013
# Iniciando gravação dos dados do ano:  2014
# Iniciando gravação dos dados do ano:  2015
# Iniciando gravação dos dados do ano:  2016
# Iniciando gravação dos dados do ano:  2017
# Iniciando gravação dos dados do ano:  2018
# Iniciando gravação dos dados do ano:  2019
# Iniciando gravação dos dados do ano:  2020
# Iniciando gravação dos dados do ano:  2021
# Iniciando gravação dos dados do ano:  2022
# Inserção finalizada 😁

# %%
SQLSelect('''
    select 
        *
    from Proposicoes
''')
# Out:
# Empty DataFrame
# Columns: [DataReuniao, DataDeliberacao, Situacao, Assunto, Autor, Proposicao, Ano, Texto]
# Index: []

# %%
SQLTruncate('Proposicoes')

# %%
#SQLSelect('''
#    select 
#        *
#    from Proposicoes
#''')

# %%
preposicao = 365
ano = 2022
url = 'https://www.legislador.com.br//LegisladorWEB.ASP?WCI=ProposicaoTexto&ID=3&TPProposicao=1&nrProposicao='+str(preposicao)+'&aaProposicao='+str(ano)
html = captura_html_pagina(url)
x = ChecaErro(url)
x
# Out:
# False
